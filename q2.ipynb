# %%
from matplotlib import pyplot as plt
import numpy as np
import draw


d_head = 341-55
d_bench = 220-55
seq1 = draw.theta_seq(1,0,d_head,55)
seq2 = draw.theta_seq(222,seq1[-1],d_bench,55)
seq = seq1[:1]+seq2
len(seq)
# Out:
# 224

# %%
plt.plot([draw.fuc_x(t) for t in seq],[draw.fuc_y(t) for t in seq],label='bench')
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
seq
# Out:
# [0,
#  32.67256359733385,
#  33.25224771093507,
#  33.821728294889276,
#  34.381530586720174,
#  34.93213601943446,
#  35.47398719008507,
#  36.0074921244197,
#  36.53302795606364,
#  37.05094411578435,
#  37.561565108453614,
#  38.06519294117162,
#  38.562109254766256,
#  39.05257720187395,
#  39.53684310755003,
#  40.01513794247207,
#  40.48767863400083,
#  40.95466923642799,
#  41.41630197849689,
#  41.87275820359545,
#  42.324209215784734,
#  42.770817042957596,
#  43.212735126852806,
#  43.65010894832759,
#  44.083076595172564,
#  44.51176927880259,
#  44.93631180534743,
#  45.35682300597313,
#  45.773416130671244,
#  46.18619920924134,
#  46.595275382751154,
#  47.00074320837653,
#  47.40269694019162,
#  47.8012267881915,
#  48.19641915757713,
#  48.58835687011263,
#  48.97711936917156,
#  49.36278290991935,
#  49.74542073592934,
#  50.125103243398144,
#  50.50189813400942,
#  50.87587055739158,
#  51.24708324402331,
#  51.615596629359096,
#  51.98146896987413,
# ...

# %%
thetas = np.linspace(0,4*2*draw.math.pi,10000)

# %%
thetas[0]
# Out:
# 0.0
